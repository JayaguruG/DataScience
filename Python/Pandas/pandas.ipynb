# %% [markdown]
# #python Pandas
# 1. dataframe
# 2. sql kind of stuff
# 3. flexibility of handling
# #Pandas is a package which is the most important tool for data scientist.
# #'Panel data'
# #Data over time - Exonometrics
# #Helps to calculate the statistics of the data easily. like min, max, sd of the product
# #Also helps in visualization
# #In background, pandas uses numpy
# #for visualization, makes use of Matplotlib

# %% [markdown]
# #Pandas first steps
# !conda install pandas
# !pip install pandas

# %%
# from google.colab import drive 
# drive.mount('/drive')

import pandas as pd

# %%
# Dataframe
# second core component of pandas series

# %%
data = {
    'Kohli' : [34,55,70,80,15],
    'Dhoni' : [15,40,30,55,10]
}

# %%
cricket_scores = pd.DataFrame(data)
cricket_scores
# Out:
#    Kohli  Dhoni
# 0     34     15
# 1     55     40
# 2     70     30
# 3     80     55
# 4     15     10

# %%
cricket_scores['Dhoni']
# Out:
# 0    15
# 1    40
# 2    30
# 3    55
# 4    10
# Name: Dhoni, dtype: int64

# %%
cricket_scores['Kohli'][0]
# Out:
# 34

# %%
# DF cols as oranges, apples - create 5 rows
fruits = {
    'apple' : [10,20,30,40,50],
    'orange' : [5,15,25,35,45]
}
fruit_data = pd.DataFrame(fruits)
display(fruit_data['apple'])
display(fruit_data['orange'])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: apple, dtype: int64
# 0     5
# 1    15
# 2    25
# 3    35
# 4    45
# Name: orange, dtype: int64

# %%
#fruits = pd.DataFrame(fruits, index = ['jan','feb','mar','apr','may','jun'])
'''
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
   1683         blocks = form_blocks(arrays, names, axes)
-> 1684         mgr = BlockManager(blocks, axes)
   1685         mgr._consolidate_inplace()

~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
    148         if do_integrity_check:
--> 149             self._verify_integrity()
    150 

~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
    325             if block.shape[1:] != mgr_shape[1:]:
--> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
    327         if len(self.items) != tot_items:

ValueError: Shape of passed values is (5, 2), indices imply (6, 2)'''
# Out:
# '\n---------------------------------------------------------------------------\nValueError                                Traceback (most recent call last)\n~\\Anaconda3\\lib\\site-packages\\pandas\\core\\internals\\managers.py in create_block_manager_from_arrays(arrays, names, axes)\n   1683         blocks = form_blocks(arrays, names, axes)\n-> 1684         mgr = BlockManager(blocks, axes)\n   1685         mgr._consolidate_inplace()\n\n~\\Anaconda3\\lib\\site-packages\\pandas\\core\\internals\\managers.py in __init__(self, blocks, axes, do_integrity_check)\n    148         if do_integrity_check:\n--> 149             self._verify_integrity()\n    150 \n\n~\\Anaconda3\\lib\\site-packages\\pandas\\core\\internals\\managers.py in _verify_integrity(self)\n    325             if block.shape[1:] != mgr_shape[1:]:\n--> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)\n    327         if len(self.items) != tot_items:\n\nValueError: Shape of passed values is
# ...

# %%
fruits = pd.DataFrame(fruits, index = ['jan','feb','mar','apr','may'])

# %%
fruits
# Out:
#      apple  orange
# jan     10       5
# feb     20      15
# mar     30      25
# apr     40      35
# may     50      45

# %%
#loc - label or name based accessing of the elements from df
#iloc
fruits.loc['jan','orange']
# Out:
# 5

# %%
fruits.loc[:, 'orange']
# Out:
# jan     5
# feb    15
# mar    25
# apr    35
# may    45
# Name: orange, dtype: int64

# %%
fruits.loc[:, ['orange', 'apple']]
# Out:
#      orange  apple
# jan       5     10
# feb      15     20
# mar      25     30
# apr      35     40
# may      45     50

# %%
# Dataframe_name.loc[row_criteria, column_criteria]

# %%
#iloc - Index based accessing

fruits.iloc[0,0:]
# Out:
# apple     10
# orange     5
# Name: jan, dtype: int64

# %%
fruits.iloc[2:4,:]
# Out:
#      apple  orange
# mar     30      25
# apr     40      35

# %%
fruits.iloc[[True, False, True, False, True]]
# Out:
#      apple  orange
# jan     10       5
# mar     30      25
# may     50      45

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
           {'a': 100, 'b': 200, 'c': 300, 'd': 400},
           {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]

# %%
df = pd.DataFrame(mydict)
df
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
df.iloc[lambda x: x.index % 2 == 0]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 2  1000  2000  3000  4000

# %%
fruits.iloc[:, lambda df: [0,1]]
# Out:
#      apple  orange
# jan     10       5
# feb     20      15
# mar     30      25
# apr     40      35
# may     50      45

# %%
fruits.head(2)
# Out:
#      apple  orange
# jan     10       5
# feb     20      15

# %%
fruits.tail(2)

# %%
fruits.index
# Out:
# Index(['jan', 'feb', 'mar', 'apr', 'may'], dtype='object')

# %%
fruits.index.tolist()
# Out:
# ['jan', 'feb', 'mar', 'apr', 'may']

# %%
fruits.values.tolist()
# Out:
# [[10, 5], [20, 15], [30, 25], [40, 35], [50, 45]]

# %%
fruits.shape
#shows rows and column count
# Out:
# (5, 2)

# %%
#methods of reading data in pandas df
fruits.loc[:,['New_col1', 'New_col2']] = None

# %%
fruits

# %%
#changing the values of a particular 
fruits.loc['mar','orange'] = 70

# %%
fruits

# %%
fruits = {
    'apple' : [10,20,30,40,50],
    'orange' : [5,15,25,35,45]
}
fruit_data = pd.DataFrame(fruits)

# %%
fruit_data
# Out:
#    apple  orange
# 0     10       5
# 1     20      15
# 2     30      25
# 3     40      35
# 4     50      45

# %%
fruit_data.values.tolist()
# Out:
# [[10, 5], [20, 15], [30, 25], [40, 35], [50, 45]]

# %%
fruit_data.iloc[0:]
# Out:
#    apple  orange
# 0     10       5
# 1     20      15
# 2     30      25
# 3     40      35
# 4     50      45

# %%
fruit_data.iloc[lambda x: x.index % 2 == 0]
# Out:
#    apple  orange
# 0     10       5
# 2     30      25
# 4     50      45

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 546C-4177
#
#  Directory of C:\Users\gjayaguru\Inceptez-Day1-Basics_of_Python
#
# 30-04-2021  19:15    <DIR>          .
# 30-04-2021  19:15    <DIR>          ..
# 27-04-2021  23:24    <DIR>          .ipynb_checkpoints
# 10-04-2021  09:57                20 helloworld.py
# 29-04-2021  20:10    <DIR>          LaxmiN
# 28-04-2021  23:44            44,013 Numpy.ipynb
# 30-04-2021  19:15            34,613 pandas.ipynb
# 17-04-2021  23:47            38,687 PythonBasics.ipynb
# 23-04-2021  22:36            14,128 Untitled.ipynb
# 23-04-2021  20:42                72 Untitled1.ipynb
# 28-04-2021  00:16             2,541 Untitled2.ipynb
#                7 File(s)        134,074 bytes
#                4 Dir(s)  109,283,295,232 bytes free

# %%
import pandas as pd
df = pd.read_csv('D:\Docs\Data_Science\data\Inceptez_batch_16-main\purchases.csv')
# if unicode error is shown, use 'r' - meaning raw in front of path
#df = pd.read_csv(r'D:\Docs\Data_Science\data\Inceptez_batch_16-main\purchases.csv')

# %%
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
df.head(1)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0

# %%
df = pd.read_csv('D:\Docs\Data_Science\data\Inceptez_batch_16-main\purchases.csv', index_col = 0)

# %%
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#import data from json
#json - javascript object notation
df = pd.read_json('D:\Docs\Data_Science\data\Inceptez_batch_16-main\purchases.json')

# %%
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#how to open a database file
# !pip install pysqlite3

# %%
import sqlite3
con = sqlite3.connect('D:\Docs\Data_Science\data\Inceptez_batch_16-main\database.db')

# %%
df = pd.read_sql_query('select * from purchases', con)
df
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
df.set_index('index')
# Out:
#         apples  oranges
# index
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#csv's from github
movies_df = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/IMDB-Movie-Data.csv')

# %%
movies_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#open an excel
import pandas as pd
df = pd.read_excel('D:\Docs\Data_Science\data\Inceptez_batch_16-main\Sample.xlsx')
#engine = 'openpyxl' - if excel does not open in older version of pandas
df
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
movies_df.loc[movies_df['Rank'] == 50]
# Out:
#     Rank          Title  Genre  \
# 49    50  The Last Face  Drama
#
#                                           Description   Director  \
# 49  A director (Charlize Theron) of an internation...  Sean Penn
#
#                                                Actors  Year  \
# 49  Charlize Theron, Javier Bardem, Adèle Exarchop...  2016
#
#     Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 49                130     3.7    987                 NaN       16.0

# %%
movies_df.loc[(movies_df['Rank'] == 50) | (movies_df['Title'] == 'Sing') ]
# Out:
#     Rank          Title                    Genre  \
# 3      4           Sing  Animation,Comedy,Family
# 49    50  The Last Face                    Drama
#
#                                           Description              Director  \
# 3   In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 49  A director (Charlize Theron) of an internation...             Sean Penn
#
#                                                Actors  Year  \
# 3   Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 49  Charlize Theron, Javier Bardem, Adèle Exarchop...  2016
#
#     Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 3                 108     7.2  60545              270.32       59.0
# 49                130     3.7    987                 NaN       16.0

# %%
movies_df.loc[(movies_df['Rank'] == 50) & (movies_df['Title'] == 'Sing') ]
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Genre, Description, Director, Actors, Year, Runtime (Minutes), Rating, Votes, Revenue (Millions), Metascore]
# Index: []

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movies_df.shape
# Out:
# (1000, 12)

# %%
movies_df.shape[0]
# Out:
# 1000

# %%
# to get the count of df
len(movies_df)
# Out:
# 1000

# %%
# na - not available
movies_df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
for i in movies_df:
    print(i)
# Out:
# Rank
# Title
# Genre
# Description
# Director
# Actors
# Year
# Runtime (Minutes)
# Rating
# Votes
# Revenue (Millions)
# Metascore

# %%
count = 0
for i in movies_df.values:
    print(i)
    count = count + 1
    if count > 50:
        break
# Out:
# [1 'Guardians of the Galaxy' 'Action,Adventure,Sci-Fi'
#  'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.'
#  'James Gunn' 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana' 2014
#  121 8.1 757074 333.13 76.0]
# [2 'Prometheus' 'Adventure,Mystery,Sci-Fi'
#  'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.'
#  'Ridley Scott'
#  'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron'
#  2012 124 7.0 485820 126.46 65.0]
# [3 'Split' 'Horror,Thriller'
#  'Three girls are kidnapped by a man with a diagnosed 23 distinct personalities. They must try to escape before the apparent emergence of a frightful new 24th.'
#  'M. Night Shyamalan'
#  'James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula' 2016
#  117 7.3 157606 138.12 62.0]
# [4 'Sing' 'Animation,Comedy,Family'
# ...

# %%
for i in movies_df['Title']:
    print(i)
# Out:
# Guardians of the Galaxy
# Prometheus
# Split
# Sing
# Suicide Squad
# The Great Wall
# La La Land
# Mindhorn
# The Lost City of Z
# Passengers
# Fantastic Beasts and Where to Find Them
# Hidden Figures
# Rogue One
# Moana
# Colossal
# The Secret Life of Pets
# Hacksaw Ridge
# Jason Bourne
# Lion
# Arrival
# Gold
# Manchester by the Sea
# Hounds of Love
# Trolls
# Independence Day: Resurgence
# Paris pieds nus
# Bahubali: The Beginning
# Dead Awake
# Bad Moms
# Assassin's Creed
# Why Him?
# Nocturnal Animals
# X-Men: Apocalypse
# Deadpool
# Resident Evil: The Final Chapter
# Captain America: Civil War
# Interstellar
# Doctor Strange
# The Magnificent Seven
# 5- 25- 77
# Sausage Party
# Moonlight
# Don't Fuck in the Woods
# The Founder
# Lowriders
# Pirates of the Caribbean: On Stranger Tides
# Miss Sloane
# Fallen
# Star Trek Beyond
# The Last Face
# Star Wars: Episode VII - The Force Awakens
# Underworld: Blood Wars
# Mother's Day
# John Wick
# The Dark Knight
# Silence
# ...

# %%
'''for i in movies_df['Titles']:
    print(i)
KeyError 
'''

# %%
movies_df.columns.tolist()
# Out:
# ['Rank',
#  'Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore']

# %%
movies_df.columns = movies_df.columns.str.lower()
movies_df.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime (minutes)', 'rating', 'votes', 'revenue (millions)',
#        'metascore'],
#       dtype='object')

# %%
movies_df.columns.str.lower()
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime (minutes)', 'rating', 'votes', 'revenue (millions)',
#        'metascore'],
#       dtype='object')
